# %%
import clientserver

client = clientserver.Client()
client.get("Bob")
# Out:
# 2026-04-09 13:35:00,780 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=63, family=2, type=1, proto=0, laddr=('127.0.0.1', 47320), raddr=('127.0.0.1', 50007)>
# 2026-04-09 13:35:00,782 - vs2lab.a1_layers.clientserver.Client - INFO - get called with harry
# 2026-04-09 13:35:00,785 - vs2lab.a1_layers.clientserver.Client - INFO - ERROR: no data found
# 2026-04-09 13:35:00,786 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# ERROR: no data found
# 'ERROR: no data found'

# %%
import clientserver

client = clientserver.Client()
client.getAll()
