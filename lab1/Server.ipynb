# %% [markdown]
# # Running server and client in separate notebooks - server part
# This is the first notebook we need to run in this constelation. Note that the client notebook needs to be run now in a separate window.

# %%
import clientserver # import from our script

server = clientserver.Server() # Create a server instance

server.serve() # start server routine in the forked process
# Out:
# 2026-04-09 13:34:52,712 - vs2lab.lab1.clientserver.Server - INFO - Server bound to socket <socket.socket fd=65, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>
# 2026-04-09 13:34:56,905 - vs2lab.lab1.clientserver.Server - INFO - Server send no data.
# 2026-04-09 13:35:00,783 - vs2lab.lab1.clientserver.Server - INFO - Server send no data.
# 2026-04-09 13:35:12,703 - vs2lab.lab1.clientserver.Server - INFO - Server send self._tel data to client.
# 2026-04-09 13:35:18,784 - vs2lab.lab1.clientserver.Server - INFO - Server send all tel data to client.

# %% [markdown]
# Finished
